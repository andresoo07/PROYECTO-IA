# %%
# Cargar librerías necesarias
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %%
# Cargar los datos
df = pd.read_csv("train.csv")
df.head()
# Out:
#        ID  PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0  904256    20212                  ENFERMERIA                 BOGOTÁ
# 1  645256    20212                     DERECHO              ATLANTICO
# 2  308367    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3  470353    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4  989032    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# 0            Estrato 3                 Si    Técnica o tecnológica incompleta
# 1            Estrato 3                 No      Técnica o tecnológica completa
# 2            Estrato 3                 Si  Secundaria (Bachillerato) completa
# 3            Estrato 4                 Si                             No sabe
# 4            Estrato 3                 Si                   Primaria completa
#
#   FAMI_TIENELAVADORA  ... ESTU_PRIVADO_LIBERTAD ESTU_PAGOMATRICULAPROPIO  \
# 0                 Si  ...                     N                       No
# 1                 Si  ...                     N                       No
# 2                 Si  ...                     N                       No
# 3                 Si  ...                     N                       No
# 4                 Si  ...                     N                       No
#
#   FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET.1  \
# 0                   Si                   Si
# 1                   Si                   No
# 2                   No                   Si
# 3                   Si                   Si
# 4                   Si                   Si
#
#                   FAMI_EDUCACIONMADRE RENDIMIENTO_GLOBAL coef_1  coef_2  \
# 0                           Postgrado         medio-alto  0.322   0.208
# 1    Técnica o tecnológica incompleta               bajo  0.311   0.215
# 2  Secundaria (Bachillerato) completa               bajo  0.297   0.214
# 3  Secundaria (Bachillerato) completa               alto  0.485   0.172
# 4                   Primaria completa         medio-bajo  0.316   0.232
#
#    coef_3  coef_4
# 0   0.310   0.267
# 1   0.292   0.264
# 2   0.305   0.264
# 3   0.252   0.190
# 4   0.285   0.294
#
# [5 rows x 21 columns]

# %%
# Revisión general
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80827 entries, 0 to 80826
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              80827 non-null  int64
#  1   PERIODO                         80827 non-null  int64
#  2   ESTU_PRGM_ACADEMICO             80827 non-null  object
#  3   ESTU_PRGM_DEPARTAMENTO          80826 non-null  object
#  4   ESTU_VALORMATRICULAUNIVERSIDAD  80087 non-null  object
#  5   ESTU_HORASSEMANATRABAJA         77194 non-null  object
#  6   FAMI_ESTRATOVIVIENDA            77032 non-null  object
#  7   FAMI_TIENEINTERNET              77703 non-null  object
#  8   FAMI_EDUCACIONPADRE             78100 non-null  object
#  9   FAMI_TIENELAVADORA              76188 non-null  object
#  10  FAMI_TIENEAUTOMOVIL             75752 non-null  object
#  11  ESTU_PRIVADO_LIBERTAD           80826 non-null  object
#  12  ESTU_PAGOMATRICULAPROPIO        80064 non-null  object
#  13  FAMI_TIENECOMPUTADOR            76348 non-null  object
#  14  FAMI_TIENEINTERNET.1            77703 non-null  object
#  15  FAMI_EDUCACIONMADRE             78041 non-null  object
#  16  RENDIMIENTO_GLOBAL              80826 non-null  object
#  17  coef_1                          80826 non-null  float64
#  18  coef_2                          80826 non-null  float64
#  19  coef_3                          80826 non-null  float64
#  20  coef_4                          80826 non-null  float64
# dtypes: float64(4), int64(2), object(15)
# memory usage: 13.0+ MB
# ID                                   0
# PERIODO                              0
# ESTU_PRGM_ACADEMICO                  0
# ESTU_PRGM_DEPARTAMENTO               1
# ESTU_VALORMATRICULAUNIVERSIDAD     740
# ESTU_HORASSEMANATRABAJA           3633
# FAMI_ESTRATOVIVIENDA              3795
# FAMI_TIENEINTERNET                3124
# FAMI_EDUCACIONPADRE               2727
# FAMI_TIENELAVADORA                4639
# FAMI_TIENEAUTOMOVIL               5075
# ESTU_PRIVADO_LIBERTAD                1
# ESTU_PAGOMATRICULAPROPIO           763
# FAMI_TIENECOMPUTADOR              4479
# FAMI_TIENEINTERNET.1              3124
# FAMI_EDUCACIONMADRE               2786
# RENDIMIENTO_GLOBAL                   1
# coef_1                               1
# coef_2                               1
# coef_3                               1
# coef_4                               1
# dtype: int64

# %%
# Eliminación de columnas irrelevantes
df = df.drop(columns=["ID", "PERIODO"])
df.head()
# Out:
#           ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0                  ENFERMERIA                 BOGOTÁ
# 1                     DERECHO              ATLANTICO
# 2       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# 0            Estrato 3                 Si    Técnica o tecnológica incompleta
# 1            Estrato 3                 No      Técnica o tecnológica completa
# 2            Estrato 3                 Si  Secundaria (Bachillerato) completa
# 3            Estrato 4                 Si                             No sabe
# 4            Estrato 3                 Si                   Primaria completa
#
#   FAMI_TIENELAVADORA FAMI_TIENEAUTOMOVIL ESTU_PRIVADO_LIBERTAD  \
# 0                 Si                  Si                     N
# 1                 Si                  No                     N
# 2                 Si                  No                     N
# 3                 Si                  No                     N
# 4                 Si                  Si                     N
#
#   ESTU_PAGOMATRICULAPROPIO FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET.1  \
# 0                       No                   Si                   Si
# 1                       No                   Si                   No
# 2                       No                   No                   Si
# 3                       No                   Si                   Si
# 4                       No                   Si                   Si
#
#                   FAMI_EDUCACIONMADRE RENDIMIENTO_GLOBAL  coef_1  coef_2  \
# 0                           Postgrado         medio-alto   0.322   0.208
# 1    Técnica o tecnológica incompleta               bajo   0.311   0.215
# 2  Secundaria (Bachillerato) completa               bajo   0.297   0.214
# 3  Secundaria (Bachillerato) completa               alto   0.485   0.172
# 4                   Primaria completa         medio-bajo   0.316   0.232
#
#    coef_3  coef_4
# 0   0.310   0.267
# 1   0.292   0.264
# 2   0.305   0.264
# 3   0.252   0.190
# 4   0.285   0.294

# %%
#Imputación de valores faltantes
missing = df.isnull().sum()
print(missing[missing > 0])


for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna("Desconocido")


for col in df.select_dtypes(include='number').columns:
    df[col] = df[col].fillna(df[col].mean())
# Out:
# ESTU_PRGM_DEPARTAMENTO               1
# ESTU_VALORMATRICULAUNIVERSIDAD     740
# ESTU_HORASSEMANATRABAJA           3633
# FAMI_ESTRATOVIVIENDA              3795
# FAMI_TIENEINTERNET                3124
# FAMI_EDUCACIONPADRE               2727
# FAMI_TIENELAVADORA                4639
# FAMI_TIENEAUTOMOVIL               5075
# ESTU_PRIVADO_LIBERTAD                1
# ESTU_PAGOMATRICULAPROPIO           763
# FAMI_TIENECOMPUTADOR              4479
# FAMI_TIENEINTERNET.1              3124
# FAMI_EDUCACIONMADRE               2786
# RENDIMIENTO_GLOBAL                   1
# coef_1                               1
# coef_2                               1
# coef_3                               1
# coef_4                               1
# dtype: int64

# %%
#Codificación One-Hot de variables categóricas
cat_cols = df.select_dtypes(include='object').columns.tolist()
print("Columnas categóricas:", cat_cols)

df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)
df_encoded.head()
# Out:
# Columnas categóricas: ['ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO', 'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA', 'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE', 'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_PRIVADO_LIBERTAD', 'ESTU_PAGOMATRICULAPROPIO', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET.1', 'FAMI_EDUCACIONMADRE', 'RENDIMIENTO_GLOBAL']
#    coef_1  coef_2  coef_3  coef_4  \
# 0   0.322   0.208   0.310   0.267
# 1   0.311   0.215   0.292   0.264
# 2   0.297   0.214   0.305   0.264
# 3   0.485   0.172   0.252   0.190
# 4   0.316   0.232   0.285   0.294
#
#    ESTU_PRGM_ACADEMICO_ACTIVIDAD FISICA Y DEPORTE  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ESTU_PRGM_ACADEMICO_ACUICULTURA  ESTU_PRGM_ACADEMICO_ADMINISTRACION  \
# 0                            False                               False
# 1                            False                               False
# 2                            False                               False
# 3                            False                               False
# 4                            False                               False
#
#    ESTU_PRGM_ACADEMICO_ADMINISTRACION  FINANCIERA  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ESTU_PRGM_ACADEMICO_ADMINISTRACION & SERVICIO  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    ESTU_PRGM_ACADEMICO_ADMINISTRACION AERONAUTICA  ...  \
# 0                                           False  ...
# 1                                           False  ...
# 2                                           False  ...
# 3                                           False  ...
# 4                                           False  ...
#
#    FAMI_EDUCACIONMADRE_Primaria completa  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                   True
#
#    FAMI_EDUCACIONMADRE_Primaria incompleta  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    FAMI_EDUCACIONMADRE_Secundaria (Bachillerato) completa  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                              False
#
#    FAMI_EDUCACIONMADRE_Secundaria (Bachillerato) incompleta  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    FAMI_EDUCACIONMADRE_Técnica o tecnológica completa  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    FAMI_EDUCACIONMADRE_Técnica o tecnológica incompleta  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    RENDIMIENTO_GLOBAL_alto  RENDIMIENTO_GLOBAL_bajo  \
# 0                    False                    False
# 1                    False                     True
# 2                    False                     True
# 3                     True                    False
# 4                    False                    False
#
#    RENDIMIENTO_GLOBAL_medio-alto  RENDIMIENTO_GLOBAL_medio-bajo
# 0                           True                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                           True
#
# [5 rows x 968 columns]

# %%
#Normalización de variables numéricas
numeric_cols = ['coef_1', 'coef_2', 'coef_3', 'coef_4']

scaler = StandardScaler()

df_encoded[numeric_cols] = scaler.fit_transform(df_encoded[numeric_cols])

# %%
#Dataset listo para modelos
print("Shape final del dataset procesado:", df_encoded.shape)
df_encoded.head()
# Out:
# Shape final del dataset procesado: (80827, 968)
#      coef_1    coef_2    coef_3    coef_4  \
# 0  0.433421 -0.549630  0.809756  0.064587
# 1  0.343344 -0.474509  0.505192  0.020594
# 2  0.228700 -0.485240  0.725155  0.020594
# 3  1.768198 -0.935971 -0.171615 -1.064580
# 4  0.384288 -0.292070  0.386751  0.460529
#
#    ESTU_PRGM_ACADEMICO_ACTIVIDAD FISICA Y DEPORTE  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ESTU_PRGM_ACADEMICO_ACUICULTURA  ESTU_PRGM_ACADEMICO_ADMINISTRACION  \
# 0                            False                               False
# 1                            False                               False
# 2                            False                               False
# 3                            False                               False
# 4                            False                               False
#
#    ESTU_PRGM_ACADEMICO_ADMINISTRACION  FINANCIERA  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    ESTU_PRGM_ACADEMICO_ADMINISTRACION & SERVICIO  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    ESTU_PRGM_ACADEMICO_ADMINISTRACION AERONAUTICA  ...  \
# 0                                           False  ...
# 1                                           False  ...
# 2                                           False  ...
# 3                                           False  ...
# 4                                           False  ...
#
#    FAMI_EDUCACIONMADRE_Primaria completa  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                   True
#
#    FAMI_EDUCACIONMADRE_Primaria incompleta  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    FAMI_EDUCACIONMADRE_Secundaria (Bachillerato) completa  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                              False
#
#    FAMI_EDUCACIONMADRE_Secundaria (Bachillerato) incompleta  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    FAMI_EDUCACIONMADRE_Técnica o tecnológica completa  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    FAMI_EDUCACIONMADRE_Técnica o tecnológica incompleta  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    RENDIMIENTO_GLOBAL_alto  RENDIMIENTO_GLOBAL_bajo  \
# 0                    False                    False
# 1                    False                     True
# 2                    False                     True
# 3                     True                    False
# 4                    False                    False
#
#    RENDIMIENTO_GLOBAL_medio-alto  RENDIMIENTO_GLOBAL_medio-bajo
# 0                           True                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                           True
#
# [5 rows x 968 columns]
